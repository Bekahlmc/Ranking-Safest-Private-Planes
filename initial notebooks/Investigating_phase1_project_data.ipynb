# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import csv

# %%
df = pd.read_csv('/Users/rebekahmclaughlin/Downloads/archive (2)/AviationData.csv', encoding='utf-8')
df.head()
# Out:
# /var/folders/8l/_21d1c153c5ff4j7j3y1l8c80000gn/T/ipykernel_9564/1775512957.py:1: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/rebekahmclaughlin/Downloads/archive (2)/AviationData.csv', encoding='utf-8')
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2    Saltville, VA  United States  36.922223 -81.878056          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38757
# Airport.Name              36185
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1382
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7096
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# ...

# %%
df['Purpose.of.flight'].value_counts()
# Out:
# Purpose.of.flight
# Personal                     49448
# Instructional                10601
# Unknown                       6802
# Aerial Application            4712
# Business                      4018
# Positioning                   1646
# Other Work Use                1264
# Ferry                          812
# Aerial Observation             794
# Public Aircraft                720
# Executive/corporate            553
# Flight Test                    405
# Skydiving                      182
# External Load                  123
# Public Aircraft - Federal      105
# Banner Tow                     101
# Air Race show                   99
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Air Race/show                   59
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# ASHO                             6
# PUBS                             4
# PUBL                             1
# ...

# %%
df['Event.Date'] = pd.to_datetime(df['Event.Date'], yearfirst=True)

# %%
df2000 = df.loc[df['Event.Date'] >= '2000-01-01']

# %%
df2000incidents = df2000.loc[df['Investigation.Type'] == 'Incident']

# %%
df2000incidents['Total.Fatal.Injuries'].value_counts()
# Out:
# Total.Fatal.Injuries
# 0.0    1726
# 1.0       5
# 3.0       1
# Name: count, dtype: int64

# %%
df2000incidents.loc[df2000incidents['Total.Fatal.Injuries'] > 0]
# Out:
#              Event.Id Investigation.Type Accident.Number Event.Date  \
# 51223  20080415X00478           Incident      ENG01RA005 2001-08-05
# 51490  20040914X01415           Incident      ENG01RA010 2001-09-15
# 56639  20040611X00786           Incident      FTW04IA147 2004-05-11
# 60756  20060605X00682           Incident      DFW06IA145 2006-05-30
# 63235  20070909X01340           Incident      DFW07IA193 2007-08-24
# 66194  20090413X62630           Incident      ERA09IA240 2009-04-12
#
#                      Location        Country   Latitude    Longitude  \
# 51223   Narsarsuaq, Greenland      Greenland        NaN          NaN
# 51490  BELO HORIZONTE, BRAZIL         Brazil        NaN          NaN
# 56639              SMI-28, GM  United States  28.886944   -92.142222
# 60756     Grand Isle 43AA, GM  United States  29.041389   -89.855278
# 63235       Colorado City, TX  United States  32.468334  -100.921111
# 66194          Fort Myers, FL  United States    263210N     0814519W
#
# ...

# %%
df2000incidents['Report.Status'].value_counts()
# Out:
# Report.Status
# Probable Cause                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     435
# ...

# %%
amateurs = df['Amateur.Built'].value_counts()
amateurs
# Out:
# Amateur.Built
# No     80312
# Yes     8475
# Name: count, dtype: int64

# %%
amateurs[1] / amateurs[0]
# Out:
# /var/folders/8l/_21d1c153c5ff4j7j3y1l8c80000gn/T/ipykernel_9564/2189823805.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   amateurs[1] / amateurs[0]
# 0.10552594879968125

# %%
amateur = df.loc[df['Amateur.Built'] == 'Yes']

# %%
amateur
# Out:
#              Event.Id Investigation.Type Accident.Number Event.Date  \
# 45     20020917X02423           Accident      MKC82DA016 1982-01-06
# 73     20020917X02289           Accident      LAX82FUG05 1982-01-10
# 99     20020917X02306           Accident      LAX82FUQ08 1982-01-17
# 124    20020917X02296           Accident      LAX82FUJ26 1982-01-19
# 143    20020917X01762           Accident      ATL82FLT02 1982-01-21
# ...               ...                ...             ...        ...
# 88744  20221109106267           Accident      ERA23LA053 2022-11-02
# 88754  20221117106305           Accident      ERA23LA063 2022-11-04
# 88812  20221123106352           Accident      WPR23FA044 2022-11-22
# 88831  20221202106403           Accident      WPR23LA052 2022-11-27
# 88835  20221130106386           Accident      WPR23FA047 2022-11-30
#
#                  Location        Country Latitude Longitude Airport.Code  \
# 45              ROLLA, MO  United States      NaN       NaN          K07
# ...

# %%
amateur['Report.Status'].value_counts()
# Out:
# Report.Status
# Probable Cause                                                                                                                                                                                                                                                                                            5563
# Foreign                                                                                                                                                                                                                                                                                                     68
# Factual                                                                                                                                                                                                                                                                                                     14
# ...

# %%
amateur['Total.Fatal.Injuries'].value_counts()
# Out:
# Total.Fatal.Injuries
# 0.0     4943
# 1.0     1714
# 2.0      576
# 3.0       39
# 4.0       14
# 7.0        4
# 5.0        4
# 6.0        2
# 8.0        1
# 35.0       1
# 18.0       1
# Name: count, dtype: int64

# %%
amateur.loc[amateur['Total.Fatal.Injuries'] == 35.0]
# Out:
#              Event.Id Investigation.Type Accident.Number Event.Date  \
# 41728  20001208X07895           Accident      DCA97WA045 1997-05-08
#
#               Location Country Latitude Longitude Airport.Code Airport.Name  \
# 41728  SHENZHEN, China   China      NaN       NaN          NaN          NaN
#
#        ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 41728  ...           Unknown         NaN                 35.0
#
#       Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# 41728                    NaN                  NaN             NaN
#
#       Weather.Condition  Broad.phase.of.flight Report.Status Publication.Date
# 41728               UNK                    NaN       Foreign              NaN
#
# [1 rows x 31 columns]

# %%
df2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41214 entries, 47675 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                41214 non-null  object
#  1   Investigation.Type      41214 non-null  object
#  2   Accident.Number         41214 non-null  object
#  3   Event.Date              41214 non-null  datetime64[ns]
#  4   Location                41198 non-null  object
#  5   Country                 41198 non-null  object
#  6   Latitude                34359 non-null  object
#  7   Longitude               34350 non-null  object
#  8   Airport.Code            24931 non-null  object
#  9   Airport.Name            25301 non-null  object
#  10  Injury.Severity         40214 non-null  object
#  11  Aircraft.damage         39146 non-null  object
#  12  Aircraft.Category       28406 non-null  object
#  13  Registration.Number     40096 non-null  object
# ...

# %%
df2000['Injury.Severity'].value_counts()[:30]
# Out:
# Injury.Severity
# Non-Fatal      30457
# Fatal           5262
# Fatal(1)        1646
# Fatal(2)        1005
# Incident         643
# Fatal(3)         329
# Minor            218
# Fatal(4)         197
# Serious          173
# Fatal(5)          76
# Fatal(6)          46
# Unavailable       43
# Fatal(7)          16
# Fatal(10)         13
# Fatal(8)          12
# Fatal(9)           7
# Fatal(11)          4
# Fatal(14)          3
# Fatal(13)          3
# Fatal(19)          3
# Fatal(20)          3
# Fatal(71)          2
# Fatal(46)          2
# Fatal(118)         2
# Fatal(92)          2
# Fatal(154)         2
# Fatal(23)          2
# Fatal(24)          2
# Fatal(113)         2
# Fatal(102)         2
# Name: count, dtype: int64

# %%
seriousinjuries = df2000.loc[df2000['Injury.Severity'] == 'Serious']

# %%
seriousinjuries['Amateur.Built']
# Out:
# 87307    No
# 87316    No
# 87322    No
# 87325    No
# 87334    No
#          ..
# 88827    No
# 88855    No
# 88866    No
# 88872    No
# 88875    No
# Name: Amateur.Built, Length: 173, dtype: object

# %%
df['Aircraft.Category'].value_counts()
# Out:
# Aircraft.Category
# Airplane             27617
# Helicopter            3440
# Glider                 508
# Balloon                231
# Gyrocraft              173
# Weight-Shift           161
# Powered Parachute       91
# Ultralight              30
# Unknown                 14
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# Rocket                   1
# ULTR                     1
# Name: count, dtype: int64

# %%
df['Injury.Severity'].value_counts()[:30]
# Out:
# Injury.Severity
# Non-Fatal      67357
# Fatal(1)        6167
# Fatal           5262
# Fatal(2)        3711
# Incident        2219
# Fatal(3)        1147
# Fatal(4)         812
# Fatal(5)         235
# Minor            218
# Serious          173
# Fatal(6)         161
# Unavailable       96
# Fatal(7)          56
# Fatal(8)          51
# Fatal(10)         32
# Fatal(9)          18
# Fatal(14)         11
# Fatal(11)         10
# Fatal(13)          9
# Fatal(12)          8
# Fatal(18)          5
# Fatal(20)          5
# Fatal(15)          5
# Fatal(25)          4
# Fatal(23)          4
# Fatal(19)          3
# Fatal(16)          3
# Fatal(34)          3
# Fatal(17)          3
# Fatal(104)         2
# Name: count, dtype: int64

# %%
statusunavail = df.loc[df['Injury.Severity'] == 'Unavailable']

# %%
statusunavail['Report.Status'].value_counts()
# Out:
# Report.Status
# Foreign           81
# Factual           10
# Probable Cause     5
# Name: count, dtype: int64

# %%
statusunavail['Aircraft.damage'].value_counts()
# Out:
# Aircraft.damage
# Substantial    59
# Destroyed      27
# Minor           3
# Name: count, dtype: int64

# %%
df['Aircraft.damage'].value_counts()
# Out:
# Aircraft.damage
# Substantial    64148
# Destroyed      18623
# Minor           2805
# Unknown          119
# Name: count, dtype: int64

# %%
unknowndamage = df.loc[df['Aircraft.damage'] == 'Unknown']

# %%
unknowndamage.isna().sum()
# Out:
# Event.Id                    0
# Investigation.Type          0
# Accident.Number             0
# Event.Date                  0
# Location                    0
# Country                     0
# Latitude                   51
# Longitude                  51
# Airport.Code               71
# Airport.Name               87
# Injury.Severity            27
# Aircraft.damage             0
# Aircraft.Category           0
# Registration.Number         0
# Make                        0
# Model                       0
# Amateur.Built               0
# Number.of.Engines          58
# Engine.Type               113
# FAR.Description             0
# Schedule                  114
# Purpose.of.flight          67
# Air.carrier                79
# Total.Fatal.Injuries        0
# Total.Serious.Injuries      0
# Total.Minor.Injuries        0
# Total.Uninjured             0
# Weather.Condition          77
# Broad.phase.of.flight     119
# Report.Status             112
# Publication.Date           67
# ...

# %%
unknowndamage['Report.Status'].value_counts()
# Out:
# Report.Status
# The pilot’s failure to extend the landing gear before landing. \r\n                                                                                                                                                 2
# The pilot’s failure to maintain proper airspeed on approach and his attempt to land on a wet runway with insufficient runway remaining, resulting in an overrun and loss of directional control.\r\n\r\n            1
# The pilot’s failure to maintain proper airspeed on approach resulting in an extended touchdown, bounced landing, and runway excursion.\r\n\r\n                                                                      1
# The loss of engine power for undetermined reasons based on available evidence. \r\n                                                                                                                                 1
# ...

# %%
unknowndamage['Injury.Severity'].value_counts()
# Out:
# Injury.Severity
# Non-Fatal    60
# Fatal        24
# Minor         4
# Serious       4
# Name: count, dtype: int64

# %%
unknowndamage['Total.Fatal.Injuries'].value_counts()
# Out:
# Total.Fatal.Injuries
# 0.0     96
# 1.0     12
# 2.0      5
# 3.0      3
# 4.0      1
# 7.0      1
# 14.0     1
# Name: count, dtype: int64

# %%
df['FAR.Description'].value_counts()
# Out:
# FAR.Description
# 091                               18221
# Part 91: General Aviation          6486
# NUSN                               1584
# NUSC                               1013
# 137                                1010
# 135                                 746
# 121                                 679
# Part 137: Agricultural              437
# UNK                                 371
# Part 135: Air Taxi & Commuter       298
# PUBU                                253
# 129                                 246
# Part 121: Air Carrier               165
# 133                                 107
# Part 129: Foreign                   100
# Non-U.S., Non-Commercial             97
# Non-U.S., Commercial                 93
# Part 133: Rotorcraft Ext. Load       32
# Unknown                              22
# Public Use                           19
# 091K                                 14
# ARMF                                  8
# Part 125: 20+ Pax,6000+ lbs           5
# ...

# %%
newdf = df.drop(df[df['Amateur.Built'] == 'Yes'].index)

# %%
newdf = newdf.drop(columns=['Amateur.Built'])

# %%
newdf = newdf.loc[df['Event.Date'] >= '2000-01-01']

# %%
newdf
# Out:
#              Event.Id Investigation.Type Accident.Number Event.Date  \
# 47675  20001212X20407           Accident      MIA00LA063 2000-01-01
# 47676  20001212X20327           Accident      ATL00FA019 2000-01-01
# 47677  20001212X20383           Accident      LAX00LA063 2000-01-02
# 47678  20001212X20382           Accident      LAX00LA062 2000-01-02
# 47679  20001212X20364           Accident      FTW00LA067 2000-01-02
# ...               ...                ...             ...        ...
# 88884  20221227106491           Accident      ERA23LA093 2022-12-26
# 88885  20221227106494           Accident      ERA23LA095 2022-12-26
# 88886  20221227106497           Accident      WPR23LA075 2022-12-26
# 88887  20221227106498           Accident      WPR23LA076 2022-12-26
# 88888  20221230106513           Accident      ERA23LA097 2022-12-29
#
#               Location        Country Latitude Longitude Airport.Code  \
# 47675    HOMESTEAD, FL  United States      NaN       NaN          NaN
# ...

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36542 entries, 47675 to 88888
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                36542 non-null  object
#  1   Investigation.Type      36542 non-null  object
#  2   Accident.Number         36542 non-null  object
#  3   Event.Date              36542 non-null  datetime64[ns]
#  4   Location                36526 non-null  object
#  5   Country                 36526 non-null  object
#  6   Latitude                30178 non-null  object
#  7   Longitude               30172 non-null  object
#  8   Airport.Code            21786 non-null  object
#  9   Airport.Name            22114 non-null  object
#  10  Injury.Severity         35543 non-null  object
#  11  Aircraft.damage         34484 non-null  object
#  12  Aircraft.Category       25128 non-null  object
#  13  Registration.Number     35487 non-null  object
# ...

# %%
newdf['Aircraft.Category'].value_counts()
# Out:
# Aircraft.Category
# Airplane             21204
# Helicopter            2989
# Glider                 433
# Balloon                199
# Weight-Shift           139
# Powered Parachute       83
# Gyrocraft               31
# Ultralight              18
# Unknown                 11
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# Rocket                   1
# Name: count, dtype: int64

# %%
newdf['Aircraft.Category'].isna().sum()
# Out:
# 11414

# %%
newdf.loc[newdf['Aircraft.Category'] == 'Unknown']
# Out:
#              Event.Id Investigation.Type Accident.Number Event.Date  \
# 68242  20100627X20107           Accident      CEN10RA345 2010-06-01
# 74960  20140421X23520           Accident      CEN14WA206 2014-04-20
# 75574  20140923X35458           Accident      CEN14WA516 2014-08-09
# 75689  20140902X43845           Incident      CEN14WA473 2014-08-28
# 75724  20140905X04621           Accident      CEN14WA484 2014-09-05
# 75833  20140923X65822           Accident      CEN14WA518 2014-09-23
# 75843  20141002X22321           Accident      CEN14WA529 2014-09-25
# 77773  20160120X82009           Incident      CEN16IA091 2016-01-12
# 82717  20190213X90627           Accident      ANC19WA013 2018-12-30
# 85071  20210706103424           Accident      GAA20WA148 2020-07-19
# 85466  20201009102120           Accident      WPR21LA011 2020-10-06
#
#                                         Location         Country Latitude  \
# 68242                           Campeche, Mexico          Mexico      NaN
# ...

# %%
newdf['Model'].value_counts()
# Out:
# Model
# 172             889
# 152             534
# 737             477
# 172N            415
# 172S            372
#                ...
# E-33C             1
# Combo FC 912      1
# 382G-44K-30       1
# SGS 1-35C         1
# GLASAIR           1
# Name: count, Length: 5724, dtype: int64

# %%
df.describe()
# Out:
#                           Event.Date  Number.of.Engines  Total.Fatal.Injuries  \
# count                          88889       82805.000000          77488.000000
# mean   1999-09-17 17:13:39.354475904           1.146585              0.647855
# min              1948-10-24 00:00:00           0.000000              0.000000
# 25%              1989-01-15 00:00:00           1.000000              0.000000
# 50%              1998-07-18 00:00:00           1.000000              0.000000
# 75%              2009-07-01 00:00:00           1.000000              0.000000
# max              2022-12-29 00:00:00           8.000000            349.000000
# std                              NaN           0.446510              5.485960
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# count            76379.000000          76956.000000     82977.000000
# mean                 0.279881              0.357061         5.325440
# ...

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36542 entries, 47675 to 88888
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                36542 non-null  object
#  1   Investigation.Type      36542 non-null  object
#  2   Accident.Number         36542 non-null  object
#  3   Event.Date              36542 non-null  datetime64[ns]
#  4   Location                36526 non-null  object
#  5   Country                 36526 non-null  object
#  6   Latitude                30178 non-null  object
#  7   Longitude               30172 non-null  object
#  8   Airport.Code            21786 non-null  object
#  9   Airport.Name            22114 non-null  object
#  10  Injury.Severity         35543 non-null  object
#  11  Aircraft.damage         34484 non-null  object
#  12  Aircraft.Category       25128 non-null  object
#  13  Registration.Number     35487 non-null  object
# ...

# %%
newdf['Aircraft.Category'].value_counts()
# Out:
# Aircraft.Category
# Airplane             21204
# Helicopter            2989
# Glider                 433
# Balloon                199
# Weight-Shift           139
# Powered Parachute       83
# Gyrocraft               31
# Ultralight              18
# Unknown                 11
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# Rocket                   1
# Name: count, dtype: int64

# %%
newdf['Aircraft.Category']
# Out:
# 47675         NaN
# 47676         NaN
# 47677         NaN
# 47678         NaN
# 47679         NaN
#            ...
# 88884         NaN
# 88885         NaN
# 88886    Airplane
# 88887         NaN
# 88888         NaN
# Name: Aircraft.Category, Length: 36542, dtype: object

# %%
newdf.head(30)
# Out:
#              Event.Id Investigation.Type Accident.Number Event.Date  \
# 47675  20001212X20407           Accident      MIA00LA063 2000-01-01
# 47676  20001212X20327           Accident      ATL00FA019 2000-01-01
# 47677  20001212X20383           Accident      LAX00LA063 2000-01-02
# 47678  20001212X20382           Accident      LAX00LA062 2000-01-02
# 47679  20001212X20364           Accident      FTW00LA067 2000-01-02
# 47680  20001212X20358           Accident      FTW00LA057 2000-01-02
# 47681  20001212X20344           Accident      DEN00FA037 2000-01-02
# 47682  20001212X20342           Incident      DCA00WA018 2000-01-02
# 47683  20001212X20402           Accident      MIA00FA060 2000-01-03
# 47684  20001212X20359           Accident      FTW00LA058 2000-01-03
# 47685  20001212X20328           Accident      ATL00FA021 2000-01-03
# 47688  20001212X20346           Accident      DEN00LA036 2000-01-04
# 47689  20001212X20403           Accident      MIA00FA064 2000-01-05
# ...

# %%
newdf['Purpose.of.flight'].value_counts()
# Out:
# Purpose.of.flight
# Personal                     18468
# Instructional                 4741
# Aerial Application            1759
# Business                      1075
# Positioning                    886
# Unknown                        789
# Other Work Use                 642
# Aerial Observation             431
# Public Aircraft                249
# Flight Test                    245
# Ferry                          191
# Executive/corporate            191
# Skydiving                      148
# External Load                  122
# Public Aircraft - Federal      104
# Banner Tow                     101
# Public Aircraft - Local         74
# Air Race show                   71
# Public Aircraft - State         64
# Glider Tow                      53
# Firefighting                    40
# Air Race/show                   39
# Air Drop                        11
# ASHO                             5
# PUBS                             4
# PUBL                             1
# ...

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'Balloon'].index)

# %%
newdf['Aircraft.Category'].value_counts()
# Out:
# Aircraft.Category
# Airplane             21204
# Helicopter            2989
# Glider                 433
# Weight-Shift           139
# Powered Parachute       83
# Gyrocraft               31
# Ultralight              18
# Unknown                 11
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# Rocket                   1
# Name: count, dtype: int64

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'Glider'].index)

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'Weight-Shift'].index)

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'Powered Parachute'].index)

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'Gyrocraft'].index)

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'Ultralight'].index)

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'WSFT'].index)

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'Powered-Lift'].index)

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'Blimp'].index)

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'UNK'].index)

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'Rocket'].index)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35618 entries, 47675 to 88888
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                35618 non-null  object
#  1   Investigation.Type      35618 non-null  object
#  2   Accident.Number         35618 non-null  object
#  3   Event.Date              35618 non-null  datetime64[ns]
#  4   Location                35602 non-null  object
#  5   Country                 35602 non-null  object
#  6   Latitude                29264 non-null  object
#  7   Longitude               29258 non-null  object
#  8   Airport.Code            21285 non-null  object
#  9   Airport.Name            21599 non-null  object
#  10  Injury.Severity         34621 non-null  object
#  11  Aircraft.damage         33657 non-null  object
#  12  Aircraft.Category       24204 non-null  object
#  13  Registration.Number     34565 non-null  object
# ...

# %%
newdf = newdf.drop(newdf[newdf['Aircraft.Category'] == 'Helicopter'].index)

# %%
newdf.describe()
# Out:
#                           Event.Date  Number.of.Engines  Total.Fatal.Injuries  \
# count                          32629       28575.000000          23193.000000
# mean   2010-06-13 20:28:46.905513472           1.180822              0.987324
# min              2000-01-01 00:00:00           0.000000              0.000000
# 25%              2004-07-04 00:00:00           1.000000              0.000000
# 50%              2009-09-30 00:00:00           1.000000              0.000000
# 75%              2016-05-14 00:00:00           1.000000              1.000000
# max              2022-12-29 00:00:00           8.000000            295.000000
# std                              NaN           0.440984              7.443249
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# count            22279.000000          22772.000000     28074.000000
# mean                 0.397145              0.345600         8.101482
# ...

# %%
newdf['Broad.phase.of.flight'].value_counts()
# Out:
# Broad.phase.of.flight
# Landing        3648
# Takeoff        2363
# Cruise         1943
# Maneuvering    1518
# Approach       1299
# Taxi            465
# Descent         384
# Climb           382
# Go-around       299
# Standing        243
# Unknown          65
# Other            19
# Name: count, dtype: int64

# %%
unknownflightphase = newdf.loc[newdf['Broad.phase.of.flight'] == 'Unknown']

# %%
unknownflightphase['Report.Status'].value_counts()
# Out:
# Report.Status
# Probable Cause    65
# Name: count, dtype: int64

# %%
newdf['Make'].isna().sum()
# Out:
# 46

# %%
newdf['Model'].value_counts()
# Out:
# Model
# 172               889
# 152               534
# 737               477
# 172N              415
# 172S              372
#                  ...
# PA-28-280           1
# P92 Super Echo      1
# C-172N              1
# HK 36 TTC           1
# GLASAIR             1
# Name: count, Length: 4929, dtype: int64

# %%
makelist= list(newdf['Make'].value_counts().index)

# %%
makelist
# Out:
# ['Cessna',
#  'CESSNA',
#  'Piper',
#  'PIPER',
#  'Beech',
#  'BOEING',
#  'BEECH',
#  'Boeing',
#  'Bell',
#  'Mooney',
#  'Robinson',
#  'Air Tractor',
#  'MOONEY',
#  'AIRBUS',
#  'CIRRUS DESIGN CORP',
#  'AIR TRACTOR INC',
#  'Bellanca',
#  'BELLANCA',
#  'Hughes',
#  'Grumman',
#  'Mcdonnell Douglas',
#  'AERONCA',
#  'Maule',
#  'MAULE',
#  'EMBRAER',
#  'Schweizer',
#  'Aeronca',
#  'De Havilland',
#  'Champion',
#  'Luscombe',
#  'AIR TRACTOR',
#  'North American',
#  'LUSCOMBE',
#  'Stinson',
#  'CHAMPION',
#  'STINSON',
#  'DEHAVILLAND',
#  'Aviat',
#  'Aero Commander',
#  'CIRRUS',
#  'NORTH AMERICAN',
#  'Airbus Industrie',
#  'Taylorcraft',
#  'GRUMMAN',
#  'Ayres',
#  'DIAMOND AIRCRAFT IND INC',
#  'AVIAT AIRCRAFT INC',
#  'AERO COMMANDER',
#  'Cirrus Design Corp.',
#  'BOMBARDIER INC',
#  'Cirrus',
#  'MCDONNELL DOUGLAS',
#  'Grumman American',
#  'Embraer',
#  'SOCATA',
#  'TAYLORCRAFT',
#  'Aerospatiale',
#  'GRUMMAN ACFT ENG COR-SCHWEIZER',
#  'Rockwell',
# ...

# %%
modellist = list(newdf['Model'].value_counts().index)

# %%
modellist
# Out:
# ['172',
#  '152',
#  '737',
#  '172N',
#  '172S',
#  '182',
#  '172M',
#  'PA-28-140',
#  'SR22',
#  '180',
#  'PA28',
#  'A36',
#  'PA-18-150',
#  '172P',
#  '150',
#  'PA-28-180',
#  'PA-28-161',
#  'PA-18',
#  'PA-28-181',
#  '170B',
#  '140',
#  '172R',
#  '208B',
#  'M20J',
#  '182P',
#  'A185F',
#  'G-164B',
#  '210',
#  '150M',
#  '7GCBC',
#  '7AC',
#  '150L',
#  'PA-12',
#  '58',
#  '182Q',
#  'PA-24-250',
#  '177',
#  'PA-32-300',
#  'PA-28R-200',
#  'PA-30',
#  'PA-31-350',
#  'M20C',
#  'SR20',
#  '7ECA',
#  'PA-22-150',
#  '172RG',
#  'A320',
#  '777',
#  '172K',
#  'J3C-65',
#  'T210N',
#  '185',
#  '8A',
#  'A188B',
#  'P210N',
#  'PA18',
#  '170',
#  '177RG',
#  'M20K',
#  'G-164A',
#  '206',
#  '206B',
#  '208',
#  '150F',
#  '120',
#  '35',
#  '747',
#  'PA-38-112',
#  'PA-23-250',
#  '182A',
#  'T210M',
#  'AT-301',
#  'PA-25-235',
#  'PA-28-235',
#  'R182',
#  'PA-34-200T',
#  '172H',
#  'PA-32-260',
#  'U206G',
#  'PA28R',
#  '150G',
#  '8GCBC',
#  'C23',
# ...

# %%
newdf['Engine.Type'].value_counts()
# Out:
# Engine.Type
# Reciprocating      22806
# Turbo Prop          1839
# Turbo Fan           1375
# Turbo Shaft          652
# Turbo Jet            266
# Unknown              203
# Geared Turbofan       12
# Electric               5
# UNK                    1
# Name: count, dtype: int64

# %%
df['Engine.Type'].value_counts()
# Out:
# Engine.Type
# Reciprocating      69530
# Turbo Shaft         3609
# Turbo Prop          3391
# Turbo Fan           2481
# Unknown             2051
# Turbo Jet            703
# Geared Turbofan       12
# Electric              10
# LR                     2
# NONE                   2
# Hybrid Rocket          1
# UNK                    1
# Name: count, dtype: int64

# %%
df['Broad.phase.of.flight'].value_counts()
# Out:
# Broad.phase.of.flight
# Landing        15428
# Takeoff        12493
# Cruise         10269
# Maneuvering     8144
# Approach        6546
# Climb           2034
# Taxi            1958
# Descent         1887
# Go-around       1353
# Standing         945
# Unknown          548
# Other            119
# Name: count, dtype: int64

# %%
newdf['Weather.Condition'].value_counts()
# Out:
# Weather.Condition
# VMC    26582
# IMC     1980
# Unk      215
# UNK       54
# Name: count, dtype: int64

# %%
newdf['Air.carrier'].value_counts()
# Out:
# Air.carrier
# Pilot                           175
# American Airlines                50
# Delta Air Lines                  43
# SOUTHWEST AIRLINES CO            42
# United Airlines                  41
#                                ...
# China Cargo Airlines              1
# Frost Flying Service              1
# U.S. Airways, Inc.                1
# ROSE RESOURCES OIL & GAS INC      1
# MC CESSNA 210N LLC                1
# Name: count, Length: 9109, dtype: int64

# %%
newdf['Schedule'].value_counts()
# Out:
# Schedule
# SCHD    2190
# NSCH    1850
# UNK      212
# Name: count, dtype: int64

# %%
newdf['Number.of.Engines'].value_counts()
# Out:
# Number.of.Engines
# 1.0    23538
# 2.0     4682
# 4.0      139
# 0.0      124
# 3.0       90
# 8.0        1
# 6.0        1
# Name: count, dtype: int64

# %%
newdf['Investigation.Type'].value_counts()
# Out:
# Investigation.Type
# Accident    30445
# Incident     2184
# Name: count, dtype: int64

# %%
df['Aircraft.damage'].value_counts()
# Out:
# Aircraft.damage
# Substantial    64148
# Destroyed      18623
# Minor           2805
# Unknown          119
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                       82248
# Brazil                                374
# Canada                                359
# Mexico                                358
# United Kingdom                        344
#                                     ...
# Seychelles                              1
# Palau                                   1
# Libya                                   1
# Saint Vincent and the Grenadines        1
# Turks and Caicos Islands                1
# Name: count, Length: 219, dtype: int64

# %%
df['Airport.Name'].value_counts()
# Out:
# Airport.Name
# Private                           240
# PRIVATE                           224
# Private Airstrip                  153
# NONE                              146
# PRIVATE STRIP                     111
#                                  ...
# STEHEKIN                            1
# OTTAWA MUNICIPAL                    1
# DWIGHT AIRPORT                      1
# PHOENIX DEER VALLEY MUNI            1
# WICHITA DWIGHT D EISENHOWER NT      1
# Name: count, Length: 24870, dtype: int64

# %%
df['Airport.Name'].isna().sum()
# Out:
# 36185

# %%
df['Purpose.of.flight'].value_counts()
# Out:
# Purpose.of.flight
# Personal                     49448
# Instructional                10601
# Unknown                       6802
# Aerial Application            4712
# Business                      4018
# Positioning                   1646
# Other Work Use                1264
# Ferry                          812
# Aerial Observation             794
# Public Aircraft                720
# Executive/corporate            553
# Flight Test                    405
# Skydiving                      182
# External Load                  123
# Public Aircraft - Federal      105
# Banner Tow                     101
# Air Race show                   99
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Air Race/show                   59
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# ASHO                             6
# PUBS                             4
# PUBL                             1
# ...

# %%
df['Make'] = df['Make'].str.upper()
df['Model'] = df['Model'].str.upper()

df['Make'] = df['Make'].str.replace('[^a-zA-Z0-9]', '')
df['Model'] = df['Model'].str.replace('[^a-zA-Z0-9]', '')

df['Make'] = df['Make'].str.replace('-', '')
df['Make'] = df['Make'].str.replace('(', '')
df['Make'] = df['Make'].str.replace(')', '')
df['Model'] = df['Model'].str.replace('-', '')
df['Model'] = df['Model'].str.replace('(', '')
df['Model'] = df['Model'].str.replace(')', '')

# %%
df['Model'].head(40)
# Out:
# 0                1083
# 1             PA24180
# 2                172M
# 3                 112
# 4                 501
# 5                 DC9
# 6                 180
# 7                 140
# 8                401B
# 9         NAVION L17B
# 10            PA28161
# 11               V35B
# 12              1730A
# 13              R172K
# 14                  A
# 15                 19
# 16               280C
# 17                180
# 18                172
# 19    WCS222 BELL 47G
# 20                152
# 21               150L
# 22              206L1
# 23            PA24180
# 24               AA5B
# 25               414A
# 26               BE58
# 27             M5235C
# 28               210L
# 29              7GCBC
# 30                182
# 31              AT301
# 32            PA28161
# 33           PA34200T
# 34              T337G
# 35           PA28R200
# 36                206
# 37                  A
# 38               PA22
# 39               PA31
# Name: Model, dtype: object
